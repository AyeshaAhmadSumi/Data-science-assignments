# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
## read the data set
earthquake_data = pd.read_csv('all_month.csv')
earthquake_data
# Out:
#                           time   latitude   longitude   depth   mag magType  \
# 0     2025-05-24T02:21:41.496Z  32.377000 -101.471000   5.000  1.20      ml
# 1     2025-05-24T02:07:34.440Z  38.834667 -122.818665   1.860  0.40      md
# 2     2025-05-24T01:55:04.430Z  38.814499 -122.832497   1.460  0.76      md
# 3     2025-05-24T01:54:13.580Z  38.834667 -122.818169   1.770  0.78      md
# 4     2025-05-24T01:26:58.060Z  33.501333 -116.507833  12.020  0.87      ml
# ...                        ...        ...         ...     ...   ...     ...
# 9224  2025-04-24T02:53:02.349Z   4.408600  -77.449200  64.967  4.30      mb
# 9225  2025-04-24T02:51:23.020Z  38.792000 -122.759003   1.750  1.08      md
# 9226  2025-04-24T02:49:36.730Z  36.560333 -121.093167   7.150  0.72      md
# 9227  2025-04-24T02:42:10.710Z  19.305500 -155.210663   3.640  1.86      ml
# 9228  2025-04-24T02:36:19.800Z  38.834167 -122.816170   1.830  1.05      md
#
# ...

# %%
eq = earthquake_data[["place", "mag"]].head(10)
eq
# Out:
#                            place   mag
# 0   14 km N of Big Spring, Texas  1.20
# 1    8 km NNW of The Geysers, CA  0.40
# 2     8 km NW of The Geysers, CA  0.76
# 3    8 km NNW of The Geysers, CA  0.78
# 4          16 km ESE of Anza, CA  0.87
# 5         7 km WSW of Corona, CA  1.12
# 6    41 km NNW of Beluga, Alaska  1.30
# 7           7 km WNW of Cobb, CA  1.00
# 8       27 km E of Clear, Alaska  0.90
# 9  5 km S of Funny River, Alaska  1.40

# %%
magnitudes = [1.20, 0.40, 0.76, 0.78, 0.87, 1.12, 1.30, 1.00, 0.90, 1.40]

# %%
# Find the maximum magnitude
max_magnitude = max(magnitudes)

# %%
# Calculate and print the percentage for each magnitude
for mag in magnitudes:
    percentage = (mag / max_magnitude) * 100
    print(f"Magnitude: {mag} → {percentage:.2f}% of max magnitude")
# Out:
# Magnitude: 1.2 → 85.71% of max magnitude
# Magnitude: 0.4 → 28.57% of max magnitude
# Magnitude: 0.76 → 54.29% of max magnitude
# Magnitude: 0.78 → 55.71% of max magnitude
# Magnitude: 0.87 → 62.14% of max magnitude
# Magnitude: 1.12 → 80.00% of max magnitude
# Magnitude: 1.3 → 92.86% of max magnitude
# Magnitude: 1.0 → 71.43% of max magnitude
# Magnitude: 0.9 → 64.29% of max magnitude
# Magnitude: 1.4 → 100.00% of max magnitude

# %%
magnitudes = [1.2, 0.4, 0.76, 0.78, 0.87, 1.12, 1.3, 1.0, 0.9, 1.4]
percentages = [85.71, 28.57, 54.29, 55.71, 62.14, 80.00, 92.86, 71.43, 64.29, 100.00]
locations = [
    "Big Spring, Texas", "The Geysers, CA", "The Geysers, CA", "The Geysers, CA", "Anza, CA",
    "Corona, CA", "Beluga, Alaska", "Cobb, CA", "Clear, Alaska", "Funny River, Alaska"
]

# %%
# bar graph
plt.figure(figsize=(10, 6))
plt.barh(locations, percentages, color='skyblue')

# Add titles and labels
plt.title("Earthquake magnitude in different locations", fontsize=14)
plt.xlabel("Percentage (%)", fontsize=12)
plt.ylabel("Location", fontsize=12)

# Display the plot
plt.tight_layout()
plt.show()

# %%
#pie chart
plt.figure(figsize=(8, 8))
plt.pie(percentages, labels=locations, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)

# Add title
plt.title("Earthquake magnitude in different locations", fontsize=14)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(8, 6))

# box plot
ax.boxplot(percentages, vert=False, patch_artist=True, boxprops=dict(facecolor='skyblue', color='blue'),
           medianprops=dict(color='red'))

# Set title and labels
ax.set_title("Earthquake magnitude in different locations", fontsize=14)
ax.set_xlabel("Percentage (%)", fontsize=12)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting the line chart
ax.plot(locations, percentages, marker='o', linestyle='--' , color='green')

# Adding title and labels
ax.set_title("Earthquake magnitude in different locations", fontsize=14)
ax.set_xlabel("Location", fontsize=12)
ax.set_ylabel("Percentage (%)", fontsize=12)

# Rotating x-axis labels for better readability
plt.xticks(rotation=360)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting the scatter plot
ax.scatter(locations, percentages, color='magenta', edgecolor='black', s=100)

# Adding title and labels
ax.set_title("Earthquake magnitude in different locations", fontsize=14)
ax.set_xlabel("Location", fontsize=10)
ax.set_ylabel("Percentage (%)", fontsize=12)

# Rotating x-axis labels for better readability
plt.xticks(rotation=360)

# Display the plot
plt.tight_layout()
plt.show()

# %%
##Conclusions
##the general observation is that the smaller earthquakes are frequent than larger ones
##most earthquake percentages are concentrated between 50% and 100% of the maximum magnitude
